# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
sp.init_printing()

# %%
x = sp.Function('x')
t = sp.Symbol('t')
w0 = sp.Symbol('omega_0', positive=True, real=True)
v0 = sp.Symbol('v_0', real=True)
x0 = sp.Symbol('x_0', real=True)

tau = sp.Symbol('tau', real=True)
beta = sp.Integer(1)/(2*tau)

x(t).diff(t, t)
# Out:
#   2
#  d
# ───(x(t))
#   2
# dt

# %%
# Wprowadzam tau jako odwrotnosc tlumienia, bo lepiej podstawić zero zamiast inf
osc_tl = sp.Eq(x(t).diff(t, t) + tau * x(t).diff(t) + w0**2 * x(t), 0)

osc_tl.subs(tau, 0)
# Out:
#              2
#   2         d
# ω₀ ⋅x(t) + ───(x(t)) = 0
#              2
#            dt

# %%
sol_tl = sp.dsolve(osc_tl, x(t), ics={x(0): x0, x(t).diff(t).subs(t, 0): v0})
display(sol_tl)
sp.plot(sol_tl.rhs.subs({x0: 0, w0: 1, v0: 1, tau: 0.1}), (t, 0, 40))
# Out:
#                                                             ⎛       __________
#                                                             ⎜      ╱       2
#                                                          -t⋅⎝τ + ╲╱  - 4⋅ω₀  +
#                                                          ─────────────────────
#        ⎛          τ⋅x₀                  v₀          x₀⎞               2
# x(t) = ⎜- ─────────────────── - ───────────────── + ──⎟⋅ℯ
#        ⎜       ______________      ______________   2 ⎟
#        ⎜      ╱       2    2      ╱       2    2      ⎟
#        ⎝  2⋅╲╱  - 4⋅ω₀  + τ     ╲╱  - 4⋅ω₀  + τ       ⎠
#
# ____⎞                                                      ⎛        __________
#   2 ⎟                                                      ⎜       ╱       2
#  τ  ⎠                                                    t⋅⎝-τ + ╲╱  - 4⋅ω₀  +
# ──────                                                   ─────────────────────
#          ⎛        τ⋅x₀                  v₀          x₀⎞              2
#        + ⎜─────────────────── + ───────────────── + ──⎟⋅ℯ
#          ⎜     ______________      ______________   2 ⎟
#          ⎜    ╱       2    2      ╱       2    2      ⎟
#          ⎝2⋅╲╱  - 4⋅ω₀  + τ     ╲╱  - 4⋅ω₀  + τ       ⎠
#
# ____⎞
#   2 ⎟
#  τ  ⎠
# ─────

# %%
sol = sp.dsolve(osc_tl.subs(tau, 0), x(t), ics={x(0): x0, x(t).diff(t).subs(t, 0): v0})
display(sol)
sp.plot(sol.rhs.subs({x0: 0, w0: 1, v0: 1}), (t, 0, 40))
# Out:
#                       v₀⋅sin(ω₀⋅t)
# x(t) = x₀⋅cos(ω₀⋅t) + ────────────
#                            ω₀

# %%
a0 = sp.Symbol('alpha_0')
osc_wym = osc_tl = sp.Eq(x(t).diff(t, t) + tau * x(t).diff(t) + w0**2 * x(t), a0 * sp.sin(w0*t))
osc_wym
# Out:
#                           2
#   2          d           d
# ω₀ ⋅x(t) + τ⋅──(x(t)) + ───(x(t)) = α₀⋅sin(ω₀⋅t)
#              dt           2
#                         dt

# %%
sol_wym = sp.dsolve(osc_tl.subs(tau, 0), x(t), ics={x(0): x0, x(t).diff(t).subs(t, 0): v0})
display(sol_wym)
sp.plot(sol_wym.rhs.subs({x0: 0, w0: 1, v0: 1, a0: 1}), (t, 0, 40))
# Out:
#        ⎛  α₀⋅t     ⎞             (α₀ + 2⋅ω₀⋅v₀)⋅sin(ω₀⋅t)
# x(t) = ⎜- ──── + x₀⎟⋅cos(ω₀⋅t) + ────────────────────────
#        ⎝  2⋅ω₀     ⎠                          2
#                                           2⋅ω₀

# %%
sol_wym_tl = sp.dsolve(osc_tl, x(t), ics={x(0): x0, x(t).diff(t).subs(t, 0): v0})
display(sol_wym_tl)
sp.plot(sol_wym_tl.rhs.subs({x0: 0, w0: 1, v0: 1, a0: 1, tau: 0.4}), (t, 0, 40))
# Out:
#
#
#
#
#          α₀⋅cos(ω₀⋅t)   ⎛            α₀               α₀             τ⋅x₀
# x(t) = - ──────────── + ⎜- ────────────────────── + ────── - ─────────────────
#              ω₀⋅τ       ⎜          ______________   2⋅ω₀⋅τ        ____________
#                         ⎜         ╱       2    2                 ╱       2
#                         ⎝  2⋅ω₀⋅╲╱  - 4⋅ω₀  + τ              2⋅╲╱  - 4⋅ω₀  + τ
#
#                                  ⎛       ______________⎞
#                                  ⎜      ╱       2    2 ⎟
#                               -t⋅⎝τ + ╲╱  - 4⋅ω₀  + τ  ⎠    ⎛
#                               ───────────────────────────   ⎜            2
#              v₀          x₀⎞               2                ⎜     4⋅α₀⋅ω₀
# ── - ───────────────── + ──⎟⋅ℯ                            + ⎜─────────────────
# __      ______________   2 ⎟                                ⎜    3           3
# 2      ╱       2    2      ⎟                                ⎝8⋅ω₀ ⋅τ - 2⋅ω₀⋅τ
#      ╲╱  - 4⋅ω₀  + τ       ⎠
#
#
#
#                                ______________
#              2                ╱       2    2            3                    3
#          α₀⋅τ          α₀⋅τ⋅╲╱  - 4⋅ω₀  + τ         4⋅ω₀ ⋅τ⋅x₀           ω₀⋅τ
#  - ───────────────── - ────────────────────── + ───────────────── - ──────────
#        3           3         3           3          3           3       3
#    8⋅ω₀ ⋅τ - 2⋅ω₀⋅τ      8⋅ω₀ ⋅τ - 2⋅ω₀⋅τ       8⋅ω₀ ⋅τ - 2⋅ω₀⋅τ    8⋅ω₀ ⋅τ -
#
#
#                                                                        ⎛
#                                                                        ⎜
#                       ______________                ______________⎞  t⋅⎝-τ + ╲
#               2      ╱       2    2                ╱       2    2 ⎟  ─────────
# ⋅x₀       ω₀⋅τ ⋅x₀⋅╲╱  - 4⋅ω₀  + τ     2⋅ω₀⋅τ⋅v₀⋅╲╱  - 4⋅ω₀  + τ  ⎟
# ─────── - ────────────────────────── - ───────────────────────────⎟⋅ℯ
#       3           3           3                 3           3     ⎟
# 2⋅ω₀⋅τ        8⋅ω₀ ⋅τ - 2⋅ω₀⋅τ              8⋅ω₀ ⋅τ - 2⋅ω₀⋅τ      ⎠
#
#
#   ______________⎞
#  ╱       2    2 ⎟
# ╱  - 4⋅ω₀  + τ  ⎠
# ─────────────────
#    2
